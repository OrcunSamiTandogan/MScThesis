# %%
try:
    if subject_autoencoder == "Free_v0": 
        subject_matrix = subject_matrix.copy()  

    elif subject_autoencoder[:5] == "Basic": 
        print("Autoencoder | Basic | Started")
        subject_autoencoders_basic = static_autoencoder.basic( target_matrix = subject_matrix,
                                                              # variables: learning rate
                                                                model_type   = 'basic' ,
                                                                variable_lr  = [1e-3,1e-4,1e-5] ,
                                                                batch_size   = 128,
                                                                num_epochs   = 5,
                                                                noise_factor = 0.3,
                                                                dropout_rate = 0.2 ,
                                                                outer_layer  = subject_outer_layer,
                                                                inner_layer  = 64 ,
                                                                    ) 

        if subject_autoencoder[-2:] == "v0": 
            print("Autoencoder | Basic | Version 0")
            subject_matrix      = subject_autoencoders_basic[0]

        elif subject_autoencoder[-2:] == "v1":
            print("Autoencoder | Basic | Version 1")
            subject_matrix      = subject_autoencoders_basic[1] 

        elif subject_autoencoder[-2:] == "v2": 
            print("Autoencoder | Basic | Version 2")
            subject_matrix      = subject_autoencoders_basic[2]  
        print("Autoencoder | Basic | Finished")

    elif subject_autoencoder[:9] == "Denoising": 
        print("Autoencoder | Denoising | Started")
        subject_autoencoders_denoising = static_autoencoder.denoising( target_matrix = subject_matrix,
                                                                    # variables: learning rate, noise_factor
                                                                    model_type   = 'denoising' ,
                                                                    variable_lr  = [1e-3, 1e-4] ,
                                                                    batch_size   = 128,
                                                                    num_epochs   = 5,
                                                                    noise_factor = [0.3,0.4],
                                                                    dropout_rate = 0.0 ,
                                                                    outer_layer  = subject_outer_layer,
                                                                    inner_layer  = 64 ,
                                                                        ) 

        if subject_autoencoder[-2:] == "v0": 
            print("Autoencoder | Denoising | Version 0")
            subject_matrix      = subject_autoencoders_denoising[0]

        elif subject_autoencoder[-2:] == "v1":
            print("Autoencoder | Denoising | Version 1")
            subject_matrix      = subject_autoencoders_denoising[1] 

        elif subject_autoencoder[-2:] == "v2": 
            print("Autoencoder | Denoising | Version 2")
            subject_matrix      = subject_autoencoders_denoising[2] 

        elif subject_autoencoder[-2:] == "v3":
            print("Autoencoder | Denoising | Version 3")
            subject_matrix      = subject_autoencoders_denoising[3] 

        print("Autoencoder | Denoising | Finished") 

    elif subject_autoencoder[:7] == "Dropout":
        print("Autoencoder | Dropout | Started")
        subject_autoencoders_dropout = static_autoencoder.dropout(  target_matrix = subject_matrix,
                                                                    model_type   = 'dropout' ,
                                                                    variable_lr  = [1e-3, 1e-4] ,
                                                                    batch_size   = 128,
                                                                    num_epochs   = 5,
                                                                    noise_factor = 0 ,
                                                                    dropout_rate = [0.1,0.2],
                                                                    outer_layer  = subject_outer_layer,
                                                                    inner_layer  = 64 ,
                  ) 

        if subject_autoencoder[-2:] == "v0": 
            print("Autoencoder | Dropout | Version 0") 
            subject_matrix      = subject_autoencoders_dropout[0]

        elif subject_autoencoder[-2:] == "v1":
            print("Autoencoder | Dropout | Version 1")
            subject_matrix      = subject_autoencoders_dropout[1] 

        elif subject_autoencoder[-2:] == "v2": 
            print("Autoencoder | Dropout | Version 2")
            subject_matrix      = subject_autoencoders_dropout[2] 
        
        elif subject_autoencoder[-2:] == "v3": 
            print("Autoencoder | Dropout | Version 3")
            subject_matrix      = subject_autoencoders_dropout[3] 
        
        print("Autoencoder | Dropout | Finished") 



    elif subject_autoencoder[:] == "Combined_Dropout":
        print("Autoencoder | Combined_Dropout | Started")
        print("Autoencoder | Combined_Dropout | Finished 5.0")
        subject_autoencoders_combined_dropout = static_autoencoder.combined_dropout( target_matrix = subject_matrix,
                                                                                    model_type         = 'combined_dropout',
                                                                                    variable_lr        = [1e-3, 1e-4] ,
                                                                                    batch_size         = 128,
                                                                                    num_epochs         = 5,
                                                                                    noise_factor       = [0.3,0.4],
                                                                                    dropout_rate       = [0.1,0.2],
                                                                                    input_outer_layer  = 3072,
                                                                                    inner_layer        = 64 ,
                                                                                    output_outer_layer = 100, 
                          )  
        print("Autoencoder | Combined_Dropout | Finished 5.1")
        subject_matrix = subject_autoencoders_combined_dropout[0]    
        print("Autoencoder | Combined_Dropout | Finished 5.2")


    elif subject_autoencoder[:8] == "Combined":
        print("Autoencoder | Combined | Started")
        subject_autoencoders_combined = static_autoencoder.combined( target_matrix   = subject_matrix,
                                                                        model_type   = 'combined'  ,
                                                                        variable_lr  = [1e-3, 1e-4], 
                                                                        batch_size   = 128,
                                                                        num_epochs   = 5,
                                                                        noise_factor = [0.3,0.4],
                                                                        dropout_rate = [0.1,0.2],
                                                                        outer_layer  = subject_outer_layer,
                                                                        inner_layer  = 64 ) 

        if subject_autoencoder[-2:] == "v0": 
            print("Autoencoder | Combined | Version 0")
            subject_matrix      = subject_autoencoders_combined[0]

        elif subject_autoencoder[-2:] == "v1":
            print("Autoencoder | Combined | Version 1")
            subject_matrix      = subject_autoencoders_combined[1] 

        elif subject_autoencoder[-2:] == "v2": 
            print("Autoencoder | Combined | Version 2")
            subject_matrix      = subject_autoencoders_combined[2] 

        elif subject_autoencoder[-2:] == "v3":
            print("Autoencoder | Combined | Version 3")
            subject_matrix      = subject_autoencoders_combined[3]
        
        elif subject_autoencoder[-2:] == "v4":
            print("Autoencoder | Combined | Version 4")
            subject_matrix      = subject_autoencoders_combined[4]
        
        elif subject_autoencoder[-2:] == "v5":
            print("Autoencoder | Combined | Version 5")
            subject_matrix      = subject_autoencoders_combined[5]
        
        elif subject_autoencoder[-2:] == "v6":
            print("Autoencoder | Combined | Version 6")
            subject_matrix      = subject_autoencoders_combined[6]
        
        elif subject_autoencoder[-2:] == "v7":
            print("Autoencoder | Combined | Version 7")
            subject_matrix      = subject_autoencoders_combined[7]
        
        print("Autoencoder | Combined | Finished") 


    print("Autoencoder | None | Finished")
except Exception as e: 
    print("Error", e)
    print("Error | Autoencoder | Static Autoencoder")
