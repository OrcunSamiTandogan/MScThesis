# %%
if subject_outlier[:7] == "Free_v0":
    free_List             = [data_embedded.copy(), target_embeddings_matrix] 
    subject_data_full     = free_List[0] 
    subject_target_matrix = free_List[1] 
    subject_outliers      = None 

elif subject_outlier[:9] == "ZScore_v0":
    print("Calculation of ZScore_v0 Started") 
    z_List   = static_outlier.calculate_z(df_target       = data_embedded.copy(), 
                                          target_matrix    = target_embeddings_matrix)    
    #ZScore_v0_data_full, ZScore_v0_target_matrix_z, ZScore_v0_z_outliers = z_List[0], z_List[1], z_List[2] 
    subject_data_full, subject_target_matrix, subject_outliers = z_List[0], z_List[1], z_List[2] 
    print("Calculation of ZScore_v0 Finished") 

elif subject_outlier[:9] == "ZScore_v1":
    print("Calculation of ZScore_v1 Started")
    z_List   = static_outlier.calculate_z(df_target       = data_embedded.copy(), 
                                          target_matrix    = target_embeddings_matrix)    
    #ZScore_v1_data_full, ZScore_v1_target_matrix_z, ZScore_v1_z_outliers = z_List[3], z_List[4], z_List[5] 
    subject_data_full, subject_target_matrix, subject_outliers = z_List[3], z_List[4], z_List[5] 
    print("Calculation of ZScore_v1 Finishedd")

elif subject_outlier[:6] == "ISO_v0":
    print("Calculation of ISO_v0 Started") 
    iso_List = static_outlier.calculate_iso(df_target         = data_embedded.copy(),
                                            target_matrix     = target_embeddings_matrix)
    #ISO_v0_data_full, ISO_v0_target_matrix_iso, ISO_v0_iso_outliers = iso_List[0], iso_List[1], iso_List[2]
    subject_data_full, subject_target_matrix, subject_outliers = iso_List[0], iso_List[1], iso_List[2] 
    print("Calculation of ISO_v0 Finished") 

elif subject_outlier[:6] == "ISO_v1":
    print("Calculation of ISO_v1 Started") 
    iso_List = static_outlier.calculate_iso(df_target         = data_embedded.copy(),
                                            target_matrix     = target_embeddings_matrix)
    #ISO_v1_data_full, ISO_v1_target_matrix_iso, ISO_v1_iso_outliers = iso_List[3], iso_List[4], iso_List[5] 
    subject_data_full, subject_target_matrix, subject_outliers = iso_List[3], iso_List[4], iso_List[5] 
    print("Calculation of ISO_v1 Finished") 

elif subject_outlier[:6] == "LOF_v0": 
    print("Calculation of LOF_v0 Started") 
    lof_List = static_outlier.calculate_lof(df_target       = data_embedded.copy(),
                                            target_matrix   = target_embeddings_matrix)
    #LOF_v0_data_full, LOF_v0_target_matrix_lof, LOF_v0_lof_outliers = lof_List[0], lof_List[1], lof_List[2] 
    subject_data_full, subject_target_matrix, subject_outliers = lof_List[0], lof_List[1], lof_List[2] 
    print("Calculation of LOF_v0 Finished") 
    
elif subject_outlier[:6] == "LOF_v1": 
    print("Calculation of LOF_v1 Started")
    lof_List = static_outlier.calculate_lof(df_target       = data_embedded.copy(),
                                            target_matrix   = target_embeddings_matrix)
    #LOF_v1_data_full, LOF_v1_target_matrix_lof, LOF_v1_lof_outliers = lof_List[3], lof_List[4], lof_List[5] 
    subject_data_full, subject_target_matrix, subject_outliers = lof_List[3], lof_List[4], lof_List[5] 
    print("Calculation of LOF_v1 Finishedd")
