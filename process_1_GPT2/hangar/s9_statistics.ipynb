# %% [markdown]
# ####

# %% [markdown]
# # `Step 9: Statistics`

# %% [markdown]
# # 0- `Config`

# %%
import pandas as pd 
import numpy as np

# %%
try: 
    if manager == 1:
        print("s1_load.ipynb running from MANAGER")
except: 
    # %run s0_config.ipynb
# Out:
# s0_config.ipynb | Started
# Current working directory: /Volumes/yeniwd/github/iThesis/backend/modules/experiments/exp1/process_1_GPT2
# Parent directory: /Volumes/yeniwd/github/iThesis/backend/modules/experiments/exp1
# Import main data folder: /Volumes/yeniwd/github/iThesis/backend/modules/experiments/exp1/process_0/progress/s1_setup
# s0_config.ipynb | Finished

# %% [markdown]
# # 1- `Load`

# %% [markdown]
# ## 1-) `SVM`

# %%
# SVM Total 
try:
    import_name = "SVM_Total"
    with open(os.path.join(export_data_path(file_total), f'SVM_Total.pkl') , 'rb') as file:
        SVM_Total = pickle.load(file)   
    print("SVM Total Data is loaded")
except:
    print("No SVM Best Total Data") 

    SVM_Total = {} 
    print("SVM Total Data is created")
# Out:
# SVM Total Data is loaded

# %% [markdown]
# ## 2-) `SGD`

# %%
# SGD Total 
try:
    import_name = "SGD_Total"
    with open(os.path.join(export_data_path(file_total), f'SGD_Total.pkl') , 'rb') as file:
        SGD_Total = pickle.load(file)   
    print("SGD Total Data is loaded")
except:
    print("No SGD Best Total Data") 

    SGD_Total = {} 
    print("SGD Total Data is created")
# Out:
# SGD Total Data is loaded

# %% [markdown]
# ## 3-) `Decision Tree`

# %%
# DT Total 
try:
    import_name = "DT_Total"
    with open(os.path.join(export_data_path(file_total), f'DT_Total.pkl') , 'rb') as file:
        DT_Total = pickle.load(file)   
    print("DT Total Data is loaded")
except:
    print("No DT Best Total Data") 

    DT_Total = {} 
    print("DT Total Data is created")
# Out:
# DT Total Data is loaded

# %% [markdown]
# ## 4-) `Random Forest`

# %%
# RF Total 
try:
    import_name = "RF_Total"
    with open(os.path.join(export_data_path(file_total), f'RF_Total.pkl') , 'rb') as file:
        RF_Total = pickle.load(file)   
    print("RF Total Data is loaded")
except:
    print("No RF Best Total Data") 

    RF_Total = {} 
    print("RF Total Data is created")
# Out:
# RF Total Data is loaded

# %% [markdown]
# ## 5-) `Gradient Boosting`

# %%
# GB Total 
try:
    import_name = "GB_Total"
    with open(os.path.join(export_data_path(file_total), f'GB_Total.pkl') , 'rb') as file:
        GB_Total = pickle.load(file)   
    print("GB Total Data is loaded")
except:
    print("No GB Best Total Data") 

    GB_Total = {} 
    print("GB Total Data is created")
# Out:
# GB Total Data is loaded

# %% [markdown]
# ---
# # 2- `Results`

# %% [markdown]
# ## 1-) `SVM`

# %%
# Number of Unique Models 
print(f"Number of Unique Models: {len(pd.unique(SVM_Total["Model"]))}")
# Out:
# Number of Unique Models: 1

# %% [markdown]
# ### A-) `Inspection: Single`

# %%
# Target 
target_model = "Free_v0_Free_v0_PCA_n2" 
# Statistics 
SVM_Total[SVM_Total["Applications"] == target_model]
# Out:
#              Applications Applications_Condition Model  \
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0   SVM
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_0   SVM
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1   SVM
#
#                                        Parameters  Accuracy  Precision  \
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.480000   0.588382
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.480000   0.588382
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.365333   0.356651
#
#      Recall        F1
# 0  0.480000  0.437347
# 0  0.480000  0.437347
# 0  0.365333  0.337417

# %% [markdown]
# ### B-) `Inspection: Best`

# %%
SVM_Total.sort_values(by="F1", ascending=False)
# Out:
#                     Applications Applications_Condition Model  \
# 0   Free_v0_Denoising_v1_PCA_n51       Out_1_Aut_1_DR_1   SVM
# 0     Free_v0_Dropout_v1_PCA_n50       Out_1_Aut_1_DR_1   SVM
# 0     Free_v0_Dropout_v3_PCA_n50       Out_1_Aut_1_DR_1   SVM
# 0   Free_v0_Denoising_v2_PCA_n51       Out_1_Aut_1_DR_1   SVM
# 0    Free_v0_Combined_v0_PCA_n50       Out_1_Aut_1_DR_1   SVM
# ..                           ...                    ...   ...
# 0      Free_v0_Dropout_v3_PCA_n2       Out_1_Aut_1_DR_1   SVM
# 0        Free_v0_Basic_v0_PCA_n2       Out_1_Aut_1_DR_1   SVM
# 0      Free_v0_Dropout_v2_PCA_n2       Out_1_Aut_1_DR_1   SVM
# 0     Free_v0_Combined_v0_PCA_n2       Out_1_Aut_1_DR_1   SVM
# 0    Free_v0_Denoising_v3_PCA_n2       Out_1_Aut_1_DR_1   SVM
#
#                                         Parameters  Accuracy  Precision  \
# 0   kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.976000   0.976429
# 0   kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.976000   0.976429
# 0   kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.976000   0.976429
# 0   kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.976000   0.976429
# 0   kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.976000   0.976429
# ..                                             ...       ...        ...
# 0   kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.365333   0.356651
# 0   kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.365333   0.356651
# 0   kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.365333   0.356651
# 0   kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.365333   0.356651
# 0   kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.365333   0.356651
#
#       Recall        F1
# 0   0.976000  0.975891
# 0   0.976000  0.975891
# 0   0.976000  0.975891
# 0   0.976000  0.975891
# 0   0.976000  0.975891
# ..       ...       ...
# 0   0.365333  0.337417
# 0   0.365333  0.337417
# 0   0.365333  0.337417
# 0   0.365333  0.337417
# 0   0.365333  0.337417
#
# [1920 rows x 8 columns]

# %% [markdown]
# ## 2-) `SVG`

# %%
# Number of Unique Models 
print(f"Number of Unique Models: {len(pd.unique(SGD_Total["Model"]))}")
# Out:
# Number of Unique Models: 1

# %% [markdown]
# ### A-) `Inspection: Single`

# %%
# Target 
target_model = "Free_v0_Free_v0_PCA_n2" 
# Statistics 
SGD_Total[SGD_Total["Applications"] == target_model]
# Out:
#              Applications Applications_Condition Model  \
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0   SGD
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_0   SGD
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1   SGD
#
#                                        Parameters  Accuracy  Precision  \
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.925333   0.942284
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.925333   0.942284
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.232000   0.285972
#
#      Recall        F1
# 0  0.925333  0.926168
# 0  0.925333  0.926168
# 0  0.232000  0.215860

# %% [markdown]
# ### B-) `Inspection: Best`

# %%
SGD_Total.sort_values(by="F1", ascending=False)
# Out:
#                                 Applications Applications_Condition Model  \
# 0                   Free_v0_Basic_v0_PCA_n50       Out_1_Aut_1_DR_1   SGD
# 0               Free_v0_Denoising_v1_PCA_n51       Out_1_Aut_1_DR_1   SGD
# 0                Free_v0_Combined_v1_PCA_n50       Out_1_Aut_1_DR_1   SGD
# 0               Free_v0_Denoising_v3_PCA_n50       Out_1_Aut_1_DR_1   SGD
# 0                   Free_v0_Basic_v2_PCA_n51       Out_1_Aut_1_DR_1   SGD
# ..                                       ...                    ...   ...
# 0     Free_v0_Dropout_v2_UMAP_nc2_nn50_min01       Out_1_Aut_1_DR_1   SGD
# 0   Free_v0_Denoising_v3_UMAP_nc2_nn50_min01       Out_1_Aut_1_DR_1   SGD
# 0       Free_v0_Basic_v1_UMAP_nc2_nn50_min01       Out_1_Aut_1_DR_1   SGD
# 0       Free_v0_Basic_v2_UMAP_nc2_nn50_min01       Out_1_Aut_1_DR_1   SGD
# 0     Free_v0_Dropout_v1_UMAP_nc2_nn50_min01       Out_1_Aut_1_DR_1   SGD
#
#                                         Parameters  Accuracy  Precision  \
# 0   alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.957333   0.961438
# 0   alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.957333   0.961438
# 0   alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.954667   0.959392
# 0   alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.954667   0.959392
# 0   alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.952000   0.957467
# ..                                             ...       ...        ...
# 0   alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.232000   0.124078
# 0   alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.232000   0.124078
# 0   alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.232000   0.124078
# 0   alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.232000   0.124078
# 0   alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.232000   0.124078
#
#       Recall        F1
# 0   0.957333  0.957942
# 0   0.957333  0.957942
# 0   0.954667  0.955258
# 0   0.954667  0.955258
# 0   0.952000  0.952790
# ..       ...       ...
# 0   0.232000  0.150255
# 0   0.232000  0.150255
# 0   0.232000  0.150255
# 0   0.232000  0.150255
# 0   0.232000  0.150255
#
# [1920 rows x 8 columns]

# %% [markdown]
# ## 3-) `Decision Tree`

# %%
# Number of Unique Models 
print(f"Number of Unique Models: {len(pd.unique(DT_Total["Model"]))}")
# Out:
# Number of Unique Models: 1

# %% [markdown]
# ### A-) `Inspection: Single`

# %%
# Target 
target_model = "Free_v0_Free_v0_PCA_n2" 
# Statistics 
DT_Total[DT_Total["Applications"] == target_model]
# Out:
#              Applications Applications_Condition Model Parameters  Accuracy  \
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0    DT      Basic     0.928
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_0    DT      Basic     0.928
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1    DT      Basic     0.328
#
#    Precision  Recall        F1
# 0   0.933154   0.928  0.928680
# 0   0.933154   0.928  0.928680
# 0   0.331787   0.328  0.325594

# %% [markdown]
# ### B-) `Inspection: Best`

# %%
DT_Total.sort_values(by="F1", ascending=False)
# Out:
#                              Applications Applications_Condition Model  \
# 0                  Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0    DT
# 0    Free_v0_Dropout_v0_TSNE_nc3_p50_lr10       Out_1_Aut_0_DR_0    DT
# 0     Free_v0_Dropout_v0_TSNE_nc2_p50_lr3       Out_1_Aut_0_DR_0    DT
# 0   Free_v0_Dropout_v0_TSNE_nc2_p30_lr500       Out_1_Aut_1_DR_0    DT
# 0   Free_v0_Dropout_v0_TSNE_nc2_p30_lr500       Out_1_Aut_0_DR_0    DT
# ..                                    ...                    ...   ...
# 0                 Free_v0_Basic_v1_PCA_n2       Out_1_Aut_1_DR_1    DT
# 0             Free_v0_Denoising_v3_PCA_n2       Out_1_Aut_1_DR_1    DT
# 0             Free_v0_Denoising_v1_PCA_n2       Out_1_Aut_1_DR_1    DT
# 0                  Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1    DT
# 0             Free_v0_Denoising_v0_PCA_n2       Out_1_Aut_1_DR_1    DT
#
#    Parameters  Accuracy  Precision  Recall        F1
# 0       Basic     0.928   0.933154   0.928  0.928680
# 0       Basic     0.928   0.933154   0.928  0.928680
# 0       Basic     0.928   0.933154   0.928  0.928680
# 0       Basic     0.928   0.933154   0.928  0.928680
# 0       Basic     0.928   0.933154   0.928  0.928680
# ..        ...       ...        ...     ...       ...
# 0       Basic     0.328   0.331787   0.328  0.325594
# 0       Basic     0.328   0.331787   0.328  0.325594
# 0       Basic     0.328   0.331787   0.328  0.325594
# 0       Basic     0.328   0.331787   0.328  0.325594
# 0       Basic     0.328   0.331787   0.328  0.325594
#
# [1920 rows x 8 columns]

# %% [markdown]
# ## 4-) `Random Forest`

# %%
# Number of Unique Models 
print(f"Number of Unique Models: {len(pd.unique(RF_Total["Model"]))}")
# Out:
# Number of Unique Models: 1

# %% [markdown]
# ### A-) `Inspection: Single`

# %%
# Target 
target_model = "Free_v0_Free_v0_PCA_n2" 
# Statistics 
RF_Total[RF_Total["Applications"] == target_model]
# Out:
#              Applications Applications_Condition Model Parameters  Accuracy  \
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0    RF      Basic  1.000000
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_0    RF      Basic  1.000000
# 0  Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1    RF      Basic  0.373333
#
#    Precision    Recall        F1
# 0   1.000000  1.000000  1.000000
# 0   1.000000  1.000000  1.000000
# 0   0.380921  0.373333  0.372939

# %% [markdown]
# ### B-) `Inspection: Best`

# %%
RF_Total.sort_values(by="F1", ascending=False)
# Out:
#                              Applications Applications_Condition Model  \
# 0                  Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0    RF
# 0              Free_v0_Dropout_v0_PCA_n51       Out_1_Aut_0_DR_0    RF
# 0   Free_v0_Dropout_v0_TSNE_nc2_p50_lr100       Out_1_Aut_0_DR_0    RF
# 0    Free_v0_Dropout_v0_TSNE_nc2_p50_lr10       Out_1_Aut_1_DR_0    RF
# 0    Free_v0_Dropout_v0_TSNE_nc2_p50_lr10       Out_1_Aut_0_DR_0    RF
# ..                                    ...                    ...   ...
# 0                 Free_v0_Basic_v1_PCA_n2       Out_1_Aut_1_DR_1    RF
# 0                 Free_v0_Basic_v0_PCA_n2       Out_1_Aut_1_DR_1    RF
# 0               Free_v0_Dropout_v2_PCA_n2       Out_1_Aut_1_DR_1    RF
# 0                  Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1    RF
# 0              Free_v0_Combined_v0_PCA_n2       Out_1_Aut_1_DR_1    RF
#
#    Parameters  Accuracy  Precision    Recall        F1
# 0       Basic  1.000000   1.000000  1.000000  1.000000
# 0       Basic  1.000000   1.000000  1.000000  1.000000
# 0       Basic  1.000000   1.000000  1.000000  1.000000
# 0       Basic  1.000000   1.000000  1.000000  1.000000
# 0       Basic  1.000000   1.000000  1.000000  1.000000
# ..        ...       ...        ...       ...       ...
# 0       Basic  0.373333   0.380921  0.373333  0.372939
# 0       Basic  0.373333   0.380921  0.373333  0.372939
# 0       Basic  0.373333   0.380921  0.373333  0.372939
# 0       Basic  0.373333   0.380921  0.373333  0.372939
# 0       Basic  0.373333   0.380921  0.373333  0.372939
#
# [1920 rows x 8 columns]

# %% [markdown]
# ## 5-) `Gradient Boosting`

# %%
try:
    # Number of Unique Models 
    print(f"Number of Unique Models: {len(pd.unique(GB_Total["Model"]))}")  
except: 
    print("No GB Total Data")
# Out:
# No GB Total Data

# %% [markdown]
# ### A-) `Inspection: Single`

# %%
try: 
    # Target 
    target_model = "Free_v0_Free_v0_PCA_n2" 
    # Statistics 
    GB_Total[GB_Total["Applications"] == target_model] 
except: 
    print("No GB Total Data")
# Out:
# No GB Total Data

# %% [markdown]
# ### B-) `Inspection: Best`

# %%
try: 
    GB_Total.sort_values(by="F1", ascending=False) 
except: 
    print("No GB Total Data")
# Out:
# No GB Total Data

# %% [markdown]
# ---
# # 3- `All In One`

# %%
All = pd.concat([SVM_Total, SGD_Total, DT_Total, RF_Total, GB_Total], axis=0) 
All.sort_values(by="F1", ascending=False).head(20)
# Out:
#                               Applications Applications_Condition Model  \
# 0                 Free_v0_Basic_v0_PCA_n50       Out_1_Aut_1_DR_1    RF
# 0    Free_v0_Denoising_v1_TSNE_nc2_p30_lr3       Out_1_Aut_0_DR_0    RF
# 0             Free_v0_Denoising_v1_PCA_n51       Out_1_Aut_1_DR_1    RF
# 0     Free_v0_Denoising_v1_TSNE_nc2_p5_lr3       Out_1_Aut_0_DR_0    RF
# 0     Free_v0_Denoising_v1_TSNE_nc2_p5_lr3       Out_1_Aut_1_DR_0    RF
# 0    Free_v0_Denoising_v1_TSNE_nc2_p5_lr10       Out_1_Aut_0_DR_0    RF
# 0    Free_v0_Denoising_v1_TSNE_nc2_p5_lr10       Out_1_Aut_1_DR_0    RF
# 0   Free_v0_Denoising_v1_TSNE_nc2_p5_lr100       Out_1_Aut_0_DR_0    RF
# 0   Free_v0_Denoising_v1_TSNE_nc2_p5_lr100       Out_1_Aut_1_DR_0    RF
# 0   Free_v0_Denoising_v1_TSNE_nc2_p5_lr500       Out_1_Aut_0_DR_0    RF
# 0   Free_v0_Denoising_v1_TSNE_nc2_p5_lr500       Out_1_Aut_1_DR_0    RF
# 0    Free_v0_Denoising_v1_TSNE_nc2_p30_lr3       Out_1_Aut_1_DR_0    RF
# 0  Free_v0_Denoising_v1_TSNE_nc2_p50_lr100       Out_1_Aut_0_DR_0    RF
# 0   Free_v0_Denoising_v1_TSNE_nc2_p30_lr10       Out_1_Aut_0_DR_0    RF
# 0   Free_v0_Denoising_v1_TSNE_nc2_p30_lr10       Out_1_Aut_1_DR_0    RF
# 0  Free_v0_Denoising_v1_TSNE_nc2_p30_lr100       Out_1_Aut_0_DR_0    RF
# 0  Free_v0_Denoising_v1_TSNE_nc2_p30_lr100       Out_1_Aut_1_DR_0    RF
# 0  Free_v0_Denoising_v1_TSNE_nc2_p30_lr500       Out_1_Aut_0_DR_0    RF
# 0  Free_v0_Denoising_v1_TSNE_nc2_p30_lr500       Out_1_Aut_1_DR_0    RF
# 0    Free_v0_Denoising_v1_TSNE_nc2_p50_lr3       Out_1_Aut_0_DR_0    RF
#
#   Parameters  Accuracy  Precision  Recall   F1
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0
# 0      Basic       1.0        1.0     1.0  1.0

# %% [markdown]
# ---
# # `End`
