# %% [markdown]
# # `Step 8: Total`

# %% [markdown]
# # 0- `Config`

# %%
import pandas as pd 
import numpy as np

# %%
try: 
    if manager == 1:
        print("s1_load.ipynb running from MANAGER")
except: 
    # %run s0_config.ipynb
# Out:
# s0_config.ipynb | Started
# Current working directory: /Volumes/yeniwd/github/iThesis/backend/modules/experiments/exp1/process_1_BERT
# Parent directory: /Volumes/yeniwd/github/iThesis/backend/modules/experiments/exp1
# Import main data folder: /Volumes/yeniwd/github/iThesis/backend/modules/experiments/exp1/process_0/progress/s1_setup
# s0_config.ipynb | Finished

# %% [markdown]
# # 1-) `Load`
# - 0-) Default
# - 1-) SVM
# - 2-) SGD
# - 3-) Decision Tree
# - 4-) Random Forest
# - 5- Gradient Boosting

# %% [markdown]
# ## 0-) `Default`

# %%
# Basic 
import_name = "subject_outlier"
with open(os.path.join(export_data_path(file_prediction), f'subject_outlier.pkl') , 'rb') as file:
    subject_outlier = pickle.load(file)   
import_name = "subject_autoencoder"
with open(os.path.join(export_data_path(file_prediction), f'subject_autoencoder.pkl') , 'rb') as file:
    subject_autoencoder = pickle.load(file)   
import_name = "subject_dimension" 
with open(os.path.join(export_data_path(file_prediction), f'subject_dimension.pkl') , 'rb') as file:
    subject_dimension = pickle.load(file)

# %% [markdown]
# ## 1-) `SVM`

# %%
# Subject
import_name = "SVM_All"
with open(os.path.join(export_data_path(file_prediction), f'SVM_All.pkl') , 'rb') as file:
    SVM_All = pickle.load(file)   

# SVM Total Statistics 
try:
    import_name = "SVM_Total"
    with open(os.path.join(export_data_path(file_total), f'SVM_Total.pkl') , 'rb') as file:
        SVM_Total = pickle.load(file)   
    print("SVM Total Data is loaded")
except:
    print("No SVM Best Total Statistics Data") 
    SVM_Total = pd.DataFrame() 
    print("SVM Total Statistics Data is created")
# Out:
# SVM Total Data is loaded

# %% [markdown]
# ## 2-) `SGD`

# %%
# Subject
import_name = "SGD_All"
with open(os.path.join(export_data_path(file_prediction), f'SGD_All.pkl') , 'rb') as file:
    SGD_All = pickle.load(file)   

# SGD Total Statistics 
try:
    import_name = "SGD_Total"
    with open(os.path.join(export_data_path(file_total), f'SGD_Total.pkl') , 'rb') as file:
        SGD_Total = pickle.load(file)   
    print("SGD Total Data is loaded")
except:
    print("No SGD Best Total Statistics Data") 
    SGD_Total = pd.DataFrame() 
    print("SGD Total Statistics Data is created")
# Out:
# SGD Total Data is loaded

# %% [markdown]
# ## 3-) `Decision Tree`

# %%
# Subject
import_name = "DT_All"
with open(os.path.join(export_data_path(file_prediction), f'DT_All.pkl') , 'rb') as file:
    DT_All = pickle.load(file)   

# DT Total Statistics 
try:
    import_name = "DT_Total"
    with open(os.path.join(export_data_path(file_total), f'DT_Total.pkl') , 'rb') as file:
        DT_Total = pickle.load(file)   
    print("DT Total Data is loaded")
except:
    print("No DT Best Total Statistics Data") 
    DT_Total = pd.DataFrame() 
    print("DT Total Statistics Data is created")
# Out:
# DT Total Data is loaded

# %% [markdown]
# ## 4-) `Random Forest`

# %%
# Subject
import_name = "RF_All"
with open(os.path.join(export_data_path(file_prediction), f'RF_All.pkl') , 'rb') as file:
    RF_All = pickle.load(file)   

# RF Total Statistics 
try:
    import_name = "RF_Total"
    with open(os.path.join(export_data_path(file_total), f'RF_Total.pkl') , 'rb') as file:
        RF_Total = pickle.load(file)   
    print("RF Total Data is loaded")
except:
    print("No RF Best Total Statistics Data") 
    RF_Total = pd.DataFrame() 
    print("RF Total Statistics Data is created")
# Out:
# RF Total Data is loaded

# %% [markdown]
# ## 5-) `Gradient Boosting`

# %%
# Subject
import_name = "GB_All"
with open(os.path.join(export_data_path(file_prediction), f'GB_All.pkl') , 'rb') as file:
    GB_All = pickle.load(file)   

# GB Total Statistics 
try:
    import_name = "GB_Total"
    with open(os.path.join(export_data_path(file_total), f'GB_Total.pkl') , 'rb') as file:
        GB_Total = pickle.load(file)   
    print("GB Total Data is loaded")
except:
    print("No GB Best Total Statistics Data") 
    GB_Total = pd.DataFrame() 
    print("GB Total Statistics Data is created")
# Out:
# GB Total Data is loaded

# %% [markdown]
# ---
# # 2-) `Bench`
# - 1-) SVM
# - 2-) SGD
# - 3-) Decision Tree
# - 4-) Random Forest
# - 5- Gradient Boosting

# %% [markdown]
# ## 1-) `SVM`

# %% [markdown]
# ### A-) `SVM Total`

# %%
SVM_All
# Out:
#                       Applications Applications_Condition Model  \
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_0_DR_0   SVM
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_1_DR_0   SVM
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_1_DR_1   SVM
#
#                                        Parameters  Accuracy  Precision  \
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.701333   0.706925
#
#      Recall        F1
# 0  0.962667  0.962490
# 0  0.962667  0.962490
# 0  0.701333  0.682295

# %%
try: 
    SVM_Total = pd.concat([SVM_Total, SVM_All], axis=0) 
    # Keep Last Update One 
    SVM_Total = SVM_Total.drop_duplicates( subset = ["Applications","Applications_Condition", "Model"], keep = "last")   
    print("New data is inserted into SVM Total Statistics")
except:
    SVM_Total = SVM_All
    print("First data is inserted into SVM Total Statistics")
# Out:
# New data is inserted into SVM Total Statistics

# %% [markdown]
# ## 2-) `Decision Tree`

# %%
DT_Total
# Out:
#               Applications Applications_Condition Model Parameters  Accuracy  \
# 0   Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0    DT      Basic  0.813333
# 0   Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_0    DT      Basic  0.813333
# 0   Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1    DT      Basic  0.205333
# 0   Free_v0_Free_v0_PCA_n3       Out_1_Aut_0_DR_0    DT      Basic  0.813333
# 0   Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_0    DT      Basic  0.813333
# 0   Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_1    DT      Basic  0.408000
# 0  Free_v0_Free_v0_PCA_n50       Out_1_Aut_0_DR_0    DT      Basic  0.813333
# 0  Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_0    DT      Basic  0.813333
# 0  Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_1    DT      Basic  0.864000
# 0  Free_v0_Free_v0_PCA_n51       Out_1_Aut_0_DR_0    DT      Basic  0.813333
# 0  Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_0    DT      Basic  0.813333
# 0  Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_1    DT      Basic  0.840000
#
#    Precision    Recall        F1
# 0   0.811625  0.813333  0.809454
# 0   0.811625  0.813333  0.809454
# 0   0.227629  0.205333  0.211487
# 0   0.811625  0.813333  0.809454
# 0   0.811625  0.813333  0.809454
# 0   0.412024  0.408000  0.406651
# 0   0.811625  0.813333  0.809454
# 0   0.811625  0.813333  0.809454
# 0   0.870399  0.864000  0.863204
# 0   0.811625  0.813333  0.809454
# 0   0.811625  0.813333  0.809454
# 0   0.844427  0.840000  0.836650

# %%
try: 
    DT_Total = pd.concat([DT_Total, DT_All], axis=0) 
    # Keep Last Update One 
    DT_Total = DT_Total.drop_duplicates( subset = ["Applications","Applications_Condition", "Model"], keep = "last")   
    print("New data is inserted into DT Total Statistics")
except:
    DT_Total = DT_All
    print("First data is inserted into DT Total Statistics")
# Out:
# New data is inserted into DT Total Statistics

# %% [markdown]
# ## 3-) `Random Forest`

# %%
RF_Total
# Out:
#               Applications Applications_Condition Model Parameters  Accuracy  \
# 0   Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0    RF      Basic  0.986667
# 0   Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_0    RF      Basic  0.986667
# 0   Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1    RF      Basic  0.229333
# 0   Free_v0_Free_v0_PCA_n3       Out_1_Aut_0_DR_0    RF      Basic  0.986667
# 0   Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_0    RF      Basic  0.986667
# 0   Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_1    RF      Basic  0.485333
# 0  Free_v0_Free_v0_PCA_n50       Out_1_Aut_0_DR_0    RF      Basic  0.986667
# 0  Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_0    RF      Basic  0.986667
# 0  Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_1    RF      Basic  0.997333
# 0  Free_v0_Free_v0_PCA_n51       Out_1_Aut_0_DR_0    RF      Basic  0.986667
# 0  Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_0    RF      Basic  0.986667
# 0  Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_1    RF      Basic  0.994667
#
#    Precision    Recall        F1
# 0   0.986821  0.986667  0.986663
# 0   0.986821  0.986667  0.986663
# 0   0.232435  0.229333  0.226945
# 0   0.986821  0.986667  0.986663
# 0   0.986821  0.986667  0.986663
# 0   0.486957  0.485333  0.479169
# 0   0.986821  0.986667  0.986663
# 0   0.986821  0.986667  0.986663
# 0   0.997432  0.997333  0.997338
# 0   0.986821  0.986667  0.986663
# 0   0.986821  0.986667  0.986663
# 0   0.994765  0.994667  0.994671

# %%
try: 
    RF_Total = pd.concat([RF_Total, RF_All], axis=0) 
    # Keep Last Update One 
    RF_Total = RF_Total.drop_duplicates( subset = ["Applications","Applications_Condition", "Model"], keep = "last")   
    print("New data is inserted into RF Total Statistics")
except:
    RF_Total = RF_All
    print("First data is inserted into RF Total Statistics")
# Out:
# New data is inserted into RF Total Statistics

# %% [markdown]
# ## 4-) `Gradient Boosting`

# %%
try: 
    GB_Total = pd.concat([GB_Total, GB_All], axis=0) 
    # Keep Last Update One 
    GB_Total = GB_Total.drop_duplicates( subset = ["Applications","Applications_Condition", "Model"], keep = "last")   
    print("New data is inserted into GB Total Statistics")
except:
    GB_Total = GB_All
    print("First data is inserted into GB Total Statistics")
# Out:
# New data is inserted into GB Total Statistics

# %% [markdown]
# ## 5-) `SGD`

# %%
SGD_Total
# Out:
#               Applications Applications_Condition Model  \
# 0   Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0   SGD
# 0   Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_0   SGD
# 0   Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1   SGD
# 0   Free_v0_Free_v0_PCA_n3       Out_1_Aut_0_DR_0   SGD
# 0   Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_0   SGD
# 0   Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_1   SGD
# 0  Free_v0_Free_v0_PCA_n50       Out_1_Aut_0_DR_0   SGD
# 0  Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_0   SGD
# 0  Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_1   SGD
# 0  Free_v0_Free_v0_PCA_n51       Out_1_Aut_0_DR_0   SGD
# 0  Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_0   SGD
# 0  Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_1   SGD
#
#                                        Parameters  Accuracy  Precision  \
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.090667   0.034567
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.261333   0.225106
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  1.000000   1.000000
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.994667   0.994812
#
#      Recall        F1
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.090667  0.048504
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.261333  0.228413
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  1.000000  1.000000
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.994667  0.994657

# %%
try: 
    SGD_Total = pd.concat([SGD_Total, SGD_All], axis=0) 
    # Keep Last Update One 
    SGD_Total = SGD_Total.drop_duplicates( subset = ["Applications","Applications_Condition", "Model"], keep = "last")   
    print("New data is inserted into SGD Total Statistics")
except:
    SGD_Total = SGD_All
    print("First data is inserted into SGD Total Statistics")
# Out:
# New data is inserted into SGD Total Statistics

# %% [markdown]
# # 3-) `All In One`
# - 1-) SVM
# - 2-) SGD
# - 3-) Decision Tree
# - 4-) Random Forest
# - 5- Gradient Boosting

# %%
All_Data = pd.concat([SVM_Total, DT_Total, RF_Total, GB_Total, SGD_Total], axis=0) 
All_Data.sort_values(by = ["F1"], ascending= False )
# Out:
#                       Applications Applications_Condition Model  \
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_1   SGD
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_1    RF
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_0_DR_0   SGD
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0   SGD
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_0   SGD
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_0   SGD
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_0   SGD
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_0_DR_0   SGD
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_0_DR_0   SGD
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_0   SGD
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_0_DR_0   SGD
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_1_DR_0   SGD
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_1    RF
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_1   SGD
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_1   SVM
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_1   SVM
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_0_DR_0    RF
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_0    RF
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_0_DR_0    RF
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_0    RF
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0    RF
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_0_DR_0    RF
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_0    RF
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_0_DR_0    RF
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_1_DR_0    RF
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_0    RF
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_0   SVM
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0   SVM
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_0_DR_0   SVM
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_0   SVM
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_0_DR_0   SVM
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_0   SVM
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_0_DR_0   SVM
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_0   SVM
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_0_DR_0   SVM
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_1_DR_0   SVM
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_1_DR_1    RF
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_1_DR_1    DT
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_1    DT
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_1    DT
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_0    DT
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_0_DR_0    DT
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_1_DR_0    DT
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_1_DR_0    DT
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_1_DR_0    DT
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_0    DT
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_0_DR_0    DT
# 0          Free_v0_Free_v0_PCA_n50       Out_1_Aut_0_DR_0    DT
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_0_DR_0    DT
# 0          Free_v0_Free_v0_PCA_n51       Out_1_Aut_0_DR_0    DT
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_1_DR_1   SVM
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_1   SVM
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_1    RF
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_1    DT
# 0  Free_v0_Free_v0_TSNE_nc2_p5_lr3       Out_1_Aut_1_DR_1   SGD
# 0           Free_v0_Free_v0_PCA_n3       Out_1_Aut_1_DR_1   SGD
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1    RF
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1   SVM
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1    DT
# 0           Free_v0_Free_v0_PCA_n2       Out_1_Aut_1_DR_1   SGD
#
#                                        Parameters  Accuracy  Precision  \
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  1.000000   1.000000
# 0                                           Basic  0.997333   0.997432
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.997333   0.997412
# 0                                           Basic  0.994667   0.994765
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.994667   0.994812
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.992000   0.991997
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.992000   0.991997
# 0                                           Basic  0.986667   0.986821
# 0                                           Basic  0.986667   0.986821
# 0                                           Basic  0.986667   0.986821
# 0                                           Basic  0.986667   0.986821
# 0                                           Basic  0.986667   0.986821
# 0                                           Basic  0.986667   0.986821
# 0                                           Basic  0.986667   0.986821
# 0                                           Basic  0.986667   0.986821
# 0                                           Basic  0.986667   0.986821
# 0                                           Basic  0.986667   0.986821
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.962667   0.965052
# 0                                           Basic  0.941333   0.941795
# 0                                           Basic  0.917333   0.917306
# 0                                           Basic  0.864000   0.870399
# 0                                           Basic  0.840000   0.844427
# 0                                           Basic  0.813333   0.811625
# 0                                           Basic  0.813333   0.811625
# 0                                           Basic  0.813333   0.811625
# 0                                           Basic  0.813333   0.811625
# 0                                           Basic  0.813333   0.811625
# 0                                           Basic  0.813333   0.811625
# 0                                           Basic  0.813333   0.811625
# 0                                           Basic  0.813333   0.811625
# 0                                           Basic  0.813333   0.811625
# 0                                           Basic  0.813333   0.811625
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.701333   0.706925
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.525333   0.568925
# 0                                           Basic  0.485333   0.486957
# 0                                           Basic  0.408000   0.412024
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.280000   0.306431
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.261333   0.225106
# 0                                           Basic  0.229333   0.232435
# 0  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.250667   0.275690
# 0                                           Basic  0.205333   0.227629
# 0  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.090667   0.034567
#
#      Recall        F1
# 0  1.000000  1.000000
# 0  0.997333  0.997338
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.997333  0.997333
# 0  0.994667  0.994671
# 0  0.994667  0.994657
# 0  0.992000  0.991959
# 0  0.992000  0.991959
# 0  0.986667  0.986663
# 0  0.986667  0.986663
# 0  0.986667  0.986663
# 0  0.986667  0.986663
# 0  0.986667  0.986663
# 0  0.986667  0.986663
# 0  0.986667  0.986663
# 0  0.986667  0.986663
# 0  0.986667  0.986663
# 0  0.986667  0.986663
# 0  0.962667  0.962490
# 0  0.962667  0.962490
# 0  0.962667  0.962490
# 0  0.962667  0.962490
# 0  0.962667  0.962490
# 0  0.962667  0.962490
# 0  0.962667  0.962490
# 0  0.962667  0.962490
# 0  0.962667  0.962490
# 0  0.962667  0.962490
# 0  0.941333  0.941045
# 0  0.917333  0.916648
# 0  0.864000  0.863204
# 0  0.840000  0.836650
# 0  0.813333  0.809454
# 0  0.813333  0.809454
# 0  0.813333  0.809454
# 0  0.813333  0.809454
# 0  0.813333  0.809454
# 0  0.813333  0.809454
# 0  0.813333  0.809454
# 0  0.813333  0.809454
# 0  0.813333  0.809454
# 0  0.813333  0.809454
# 0  0.701333  0.682295
# 0  0.525333  0.505684
# 0  0.485333  0.479169
# 0  0.408000  0.406651
# 0  0.280000  0.235054
# 0  0.261333  0.228413
# 0  0.229333  0.226945
# 0  0.250667  0.219262
# 0  0.205333  0.211487
# 0  0.090667  0.048504

# %% [markdown]
# ---
# # `End`
# - 1-) SVM
# - 2-) SGD
# - 3-) Decision Tree
# - 4-) Random Forest
# - 5- Gradient Boosting

# %%
export_name = "SVM_Total"
with open(os.path.join(export_data_path(file_total),  export_name + ".pkl")  , 'wb') as file:
    pickle.dump(SVM_Total, file)

# %%
export_name = "DT_Total"
with open(os.path.join(export_data_path(file_total),  export_name + ".pkl")  , 'wb') as file:
    pickle.dump(DT_Total, file)

# %%
export_name = "RF_Total"
with open(os.path.join(export_data_path(file_total),  export_name + ".pkl")  , 'wb') as file:
    pickle.dump(RF_Total, file)

# %%
export_name = "GB_Total"
with open(os.path.join(export_data_path(file_total),  export_name + ".pkl")  , 'wb') as file:
    pickle.dump(GB_Total, file)

# %%
export_name = "SGD_Total"
with open(os.path.join(export_data_path(file_total),  export_name + ".pkl")  , 'wb') as file:
    pickle.dump(SGD_Total, file)
