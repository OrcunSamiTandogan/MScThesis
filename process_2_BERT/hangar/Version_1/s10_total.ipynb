# %% [markdown]
# # `Step 8: Total`

# %% [markdown]
# # 0- `Config`

# %%
import pandas as pd 
import numpy as np 
import pickle

# %%
try: 
    if manager == 1:
        print("s1_load.ipynb running from MANAGER")
except: 
    # %run s0_config.ipynb
# Out:
# s0_config.ipynb | Started
# s0_config.ipynb | Finished

# %% [markdown]
# # 1-) `Load`
# - 0-) Default
# - 1-) SVM
# - 2-) SGD
# - 3-) Decision Tree
# - 4-) Random Forest
# - 5- Gradient Boosting

# %% [markdown]
# ## 0-) `Default`

# %%
# Basic 
import_name = "subject_outlier"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_prediction}", f"{import_name}" + ".pkl"))  , 'rb') as file: 
    subject_outlier = pickle.load(file)   

import_name = "subject_autoencoder"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_prediction}", f"{import_name}" + ".pkl"))  , 'rb') as file: 
    subject_autoencoder = pickle.load(file)  
     
import_name = "subject_dimension" 
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_prediction}", f"{import_name}" + ".pkl"))  , 'rb') as file: 
    subject_dimension = pickle.load(file)

# %% [markdown]
# ## 0-) `NN`

# %%
# Subject
import_name = "NN_All"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_prediction}", f"{import_name}.pkl")), 'rb') as file: 
    NN_All = pickle.load(file)   

# SVM Total Statistics 
try:
    import_name = "NN_Total"
    with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_total}", f"{import_name}" + ".pkl"))  , 'rb') as file: 
        NN_Total = pickle.load(file)   
    print("NN Total Data is loaded")
except:
    print("No NN Best Total Statistics Data") 
    NN_Total = pd.DataFrame() 
    print("NN Total Statistics Data is created")
# Out:
# NN Total Data is loaded

# %%
import_name = "NN_All"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_prediction}", f"{import_name}.pkl")), 'rb') as file: 
    NN_All = pickle.load(file)

# %%
NN_All
# Out:
#                                         Applications  \
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
#
#         Applications_Condition Model  \
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
#
#                                           Parameters  Accuracy  Precision  \
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.535556   0.481481
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.744444   0.477778
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.153333   0.305556
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.108889   0.129630
#
#      Recall        F1
# 0  0.555556  0.470370
# 0  0.666667  0.546296
# 0  0.444444  0.359788
# 0  0.222222  0.142857

# %%
NN_Total
# Out:
#                                         Applications  \
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
#
#         Applications_Condition Model  \
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
#
#                                           Parameters  Accuracy  Precision  \
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.921502   0.941788
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.977959   0.987830
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.082664   0.004756
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.141842   0.108369
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.939400   0.954982
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.920484   0.959412
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.934328   0.956680
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.407762   0.486494
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.933047   0.951347
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.921694   0.960654
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.940650   0.957126
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.425396   0.514291
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.615556   0.388889
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.700000   0.314815
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.195556   0.272222
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.151111   0.240741
#
#      Recall        F1
# 0  0.917241  0.906983
# 0  0.986207  0.985653
# 0  0.068966  0.008899
# 0  0.144828  0.118488
# 0  0.943038  0.938256
# 0  0.943038  0.934345
# 0  0.943038  0.933462
# 0  0.405063  0.398171
# 0  0.930380  0.922493
# 0  0.943038  0.934821
# 0  0.936709  0.929353
# 0  0.449367  0.416604
# 0  0.555556  0.449735
# 0  0.444444  0.351852
# 0  0.444444  0.322751
# 0  0.333333  0.253968

# %% [markdown]
# ## 1-) `SVM`

# %%
# Subject
import_name = "SVM_All"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_prediction}", f"{import_name}.pkl")), 'rb') as file: 
    SVM_All = pickle.load(file)   

# SVM Total Statistics 
try:
    import_name = "SVM_Total"
    with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_total}", f"{import_name}" + ".pkl"))  , 'rb') as file: 
        SVM_Total = pickle.load(file)   
    print("SVM Total Data is loaded")
except:
    print("No SVM Best Total Statistics Data") 
    SVM_Total = pd.DataFrame() 
    print("SVM Total Statistics Data is created")
# Out:
# SVM Total Data is loaded

# %% [markdown]
# ## 2-) `SGD`

# %%
# Subject
import_name = "SGD_All"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_prediction}", f"{import_name}.pkl")), 'rb') as file: 
    SGD_All = pickle.load(file)   

# SGD Total Statistics 
try:
    import_name = "SGD_Total"
    with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_total}", f"{import_name}.pkl")), 'rb') as file: 
        SGD_Total = pickle.load(file)   
    print("SGD Total Data is loaded")
except:
    print("No SGD Best Total Statistics Data") 
    SGD_Total = pd.DataFrame() 
    print("SGD Total Statistics Data is created")
# Out:
# SGD Total Data is loaded

# %% [markdown]
# ## 3-) `Decision Tree`

# %%
# Subject
import_name = "DT_All"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_prediction}", f"{import_name}.pkl")), 'rb') as file: 
    DT_All = pickle.load(file)   

# DT Total Statistics 
try:
    import_name = "DT_Total"
    with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_total}", f"{import_name}.pkl")), 'rb') as file: 
        DT_Total = pickle.load(file)   
    print("DT Total Data is loaded")
except:
    print("No DT Best Total Statistics Data") 
    DT_Total = pd.DataFrame() 
    print("DT Total Statistics Data is created")
# Out:
# DT Total Data is loaded

# %% [markdown]
# ## 4-) `Random Forest`

# %%
# Subject
import_name = "RF_All"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_prediction}", f"{import_name}.pkl")), 'rb') as file: 
    RF_All = pickle.load(file)   

# RF Total Statistics 
try:
    import_name = "RF_Total"
    with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_total}", f"{import_name}.pkl")), 'rb') as file: 
        RF_Total = pickle.load(file)   
    print("RF Total Data is loaded")
except:
    print("No RF Best Total Statistics Data") 
    RF_Total = pd.DataFrame() 
    print("RF Total Statistics Data is created")
# Out:
# RF Total Data is loaded

# %% [markdown]
# ## 5-) `Gradient Boosting`

# %%
# Subject
import_name = "GB_All"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_prediction}", f"{import_name}.pkl")), 'rb') as file: 
    GB_All = pickle.load(file)   

# GB Total Statistics 
try:
    import_name = "GB_Total"
    with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_prediction}", f"{import_name}.pkl")), 'rb') as file: 
        GB_Total = pickle.load(file)   
    print("GB Total Data is loaded")
except:
    print("No GB Best Total Statistics Data") 
    GB_Total = pd.DataFrame() 
    print("GB Total Statistics Data is created")
# Out:
# No GB Best Total Statistics Data
# GB Total Statistics Data is created

# %%
# Subject
import_name = "model_Library_Current"
with open(os.path.join(access_data_path(f"{process_barcode}/model/library", f"{import_name}.pkl")), 'rb') as file: 
    model_Library_Current = pickle.load(file)   


try:
    import_name = "model_Library_Total"
    with open(os.path.join(access_data_path(f"{process_barcode}/model/library", f"{import_name}.pkl")), 'rb') as file: 
        model_Library_Total = pickle.load(file)   
    print("model_Library Total Data is loaded")
except:
    print("No model_Library Best Total Statistics Data") 
    model_Library_Total = pd.DataFrame() 
    print("model_Library Total Statistics Data is created")
# Out:
# No model_Library Best Total Statistics Data
# model_Library Total Statistics Data is created

# %% [markdown]
# ---
# # 2-) `Bench`
# - 1-) SVM
# - 2-) SGD
# - 3-) Decision Tree
# - 4-) Random Forest
# - 5- Gradient Boosting

# %% [markdown]
# ## 0-) `NN`

# %% [markdown]
# ### A-) `NN Total`

# %%
NN_All
# Out:
#                                         Applications  \
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
#
#         Applications_Condition Model  \
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
#
#                                           Parameters  Accuracy  Precision  \
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.535556   0.481481
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.744444   0.477778
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.153333   0.305556
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.108889   0.129630
#
#      Recall        F1
# 0  0.555556  0.470370
# 0  0.666667  0.546296
# 0  0.444444  0.359788
# 0  0.222222  0.142857

# %%
try: 
    NN_Total = pd.concat([NN_Total, NN_All], axis=0) 
    # Keep Last Update One 
    NN_Total = NN_Total.drop_duplicates( subset = ["Applications","Applications_Condition", "Model"], keep = "last")   
    print("New data is inserted into NN Total Statistics")
except:
    NN_Total = NN_All
    print("First data is inserted into NN Total Statistics")
# Out:
# New data is inserted into NN Total Statistics

# %%
NN_Total
# Out:
#                                         Applications  \
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
#
#         Applications_Condition Model  \
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
#
#                                           Parameters  Accuracy  Precision  \
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.921502   0.941788
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.977959   0.987830
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.082664   0.004756
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.141842   0.108369
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.939400   0.954982
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.920484   0.959412
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.934328   0.956680
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.407762   0.486494
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.933047   0.951347
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.921694   0.960654
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.940650   0.957126
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.425396   0.514291
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.535556   0.481481
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.744444   0.477778
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.153333   0.305556
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.108889   0.129630
#
#      Recall        F1
# 0  0.917241  0.906983
# 0  0.986207  0.985653
# 0  0.068966  0.008899
# 0  0.144828  0.118488
# 0  0.943038  0.938256
# 0  0.943038  0.934345
# 0  0.943038  0.933462
# 0  0.405063  0.398171
# 0  0.930380  0.922493
# 0  0.943038  0.934821
# 0  0.936709  0.929353
# 0  0.449367  0.416604
# 0  0.555556  0.470370
# 0  0.666667  0.546296
# 0  0.444444  0.359788
# 0  0.222222  0.142857

# %% [markdown]
# ## 1-) `SVM`

# %% [markdown]
# ### A-) `SVM Total`

# %%
SVM_All
# Out:
#                                         Applications  Applications_Condition  \
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_0_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_1_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_1_DR_1
#
#   Model                                      Parameters  Accuracy  Precision  \
# 0   SVM  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale       0.3   0.116667
# 0   SVM  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale       0.7   0.883333
# 0   SVM  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale       0.1   0.020000
# 0   SVM  kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale       0.1   0.033333
#
#    Recall        F1
# 0     0.3  0.161905
# 0     0.7  0.725000
# 0     0.1  0.033333
# 0     0.1  0.050000

# %%
try: 
    SVM_Total = pd.concat([SVM_Total, SVM_All], axis=0) 
    # Keep Last Update One 
    SVM_Total = SVM_Total.drop_duplicates( subset = ["Applications","Applications_Condition", "Model"], keep = "last")   
    print("New data is inserted into SVM Total Statistics")
except:
    SVM_Total = SVM_All
    print("First data is inserted into SVM Total Statistics")
# Out:
# New data is inserted into SVM Total Statistics

# %% [markdown]
# ## 2-) `Decision Tree`

# %%
DT_Total
# Out:
#                                         Applications  Applications_Condition  \
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_0_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_1_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_1_Aut_1_DR_0
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_1_Aut_1_DR_1
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_0_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_1_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_1_Aut_1_DR_0
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_1_Aut_1_DR_1
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_0_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_1_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_1_Aut_1_DR_0
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_1_Aut_1_DR_1
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_0_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_1_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_1_DR_1
#
#   Model Parameters  Accuracy  Precision    Recall        F1
# 0    DT      Basic  0.931507   0.937690  0.931507  0.931468
# 0    DT      Basic  0.931507   0.937690  0.931507  0.931468
# 0    DT      Basic  0.424658   0.456349  0.424658  0.433847
# 0    DT      Basic  0.410959   0.477235  0.410959  0.424115
# 0    DT      Basic  0.949686   0.952422  0.949686  0.948669
# 0    DT      Basic  0.949686   0.952422  0.949686  0.948669
# 0    DT      Basic  0.949686   0.952422  0.949686  0.948669
# 0    DT      Basic  0.578616   0.597172  0.578616  0.573537
# 0    DT      Basic  0.949686   0.952422  0.949686  0.948669
# 0    DT      Basic  0.949686   0.952422  0.949686  0.948669
# 0    DT      Basic  0.949686   0.952422  0.949686  0.948669
# 0    DT      Basic  0.578616   0.597172  0.578616  0.573537
# 0    DT      Basic  0.500000   0.608333  0.500000  0.516667
# 0    DT      Basic  0.500000   0.608333  0.500000  0.516667
# 0    DT      Basic  0.800000   0.900000  0.800000  0.808333
# 0    DT      Basic  0.700000   0.850000  0.700000  0.741667

# %%
try: 
    DT_Total = pd.concat([DT_Total, DT_All], axis=0) 
    # Keep Last Update One 
    DT_Total = DT_Total.drop_duplicates( subset = ["Applications","Applications_Condition", "Model"], keep = "last")   
    print("New data is inserted into DT Total Statistics")
except:
    DT_Total = DT_All
    print("First data is inserted into DT Total Statistics")
# Out:
# New data is inserted into DT Total Statistics

# %% [markdown]
# ## 3-) `Random Forest`

# %%
RF_Total
# Out:
#                                         Applications  Applications_Condition  \
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_0_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_1_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_1_Aut_1_DR_0
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_1_Aut_1_DR_1
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_0_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_1_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_1_Aut_1_DR_0
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_1_Aut_1_DR_1
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_0_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_1_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_1_Aut_1_DR_0
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_1_Aut_1_DR_1
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_0_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_1_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_1_DR_1
#
#   Model Parameters  Accuracy  Precision    Recall        F1
# 0    RF      Basic  1.000000   1.000000  1.000000  1.000000
# 0    RF      Basic  1.000000   1.000000  1.000000  1.000000
# 0    RF      Basic  0.342466   0.376925  0.342466  0.351322
# 0    RF      Basic  0.383562   0.459386  0.383562  0.400520
# 0    RF      Basic  1.000000   1.000000  1.000000  1.000000
# 0    RF      Basic  1.000000   1.000000  1.000000  1.000000
# 0    RF      Basic  1.000000   1.000000  1.000000  1.000000
# 0    RF      Basic  0.635220   0.635354  0.635220  0.622297
# 0    RF      Basic  1.000000   1.000000  1.000000  1.000000
# 0    RF      Basic  1.000000   1.000000  1.000000  1.000000
# 0    RF      Basic  1.000000   1.000000  1.000000  1.000000
# 0    RF      Basic  0.635220   0.635354  0.635220  0.622297
# 0    RF      Basic  0.600000   0.700000  0.600000  0.608333
# 0    RF      Basic  0.600000   0.700000  0.600000  0.608333
# 0    RF      Basic  0.600000   0.700000  0.600000  0.608333
# 0    RF      Basic  0.600000   0.833333  0.600000  0.645714

# %%
try: 
    RF_Total = pd.concat([RF_Total, RF_All], axis=0) 
    # Keep Last Update One 
    RF_Total = RF_Total.drop_duplicates( subset = ["Applications","Applications_Condition", "Model"], keep = "last")   
    print("New data is inserted into RF Total Statistics")
except:
    RF_Total = RF_All
    print("First data is inserted into RF Total Statistics")
# Out:
# New data is inserted into RF Total Statistics

# %% [markdown]
# ## 4-) `Gradient Boosting`

# %%
try: 
    GB_Total = pd.concat([GB_Total, GB_All], axis=0) 
    # Keep Last Update One 
    GB_Total = GB_Total.drop_duplicates( subset = ["Applications","Applications_Condition", "Model"], keep = "last")   
    print("New data is inserted into GB Total Statistics")
except:
    GB_Total = GB_All
    print("First data is inserted into GB Total Statistics")
# Out:
# New data is inserted into GB Total Statistics

# %% [markdown]
# ## 5-) `SGD`

# %%
SGD_Total
# Out:
#                                         Applications  Applications_Condition  \
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_0_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_1_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_1_Aut_1_DR_0
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...  Out_1_Nor_1_Aut_1_DR_1
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_0_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_1_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_1_Aut_1_DR_0
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...  Out_1_Nor_1_Aut_1_DR_1
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_0_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_1_Aut_0_DR_0
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_1_Aut_1_DR_0
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...  Out_1_Nor_1_Aut_1_DR_1
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_0_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_0_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_1_DR_0
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...  Out_1_Nor_1_Aut_1_DR_1
#
#   Model                                      Parameters  Accuracy  Precision  \
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.500000   0.731398
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  1.000000   1.000000
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.082192   0.007096
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.171233   0.073199
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.748428   0.719200
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.748428   0.719200
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.748428   0.719200
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.396226   0.328926
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.748428   0.719200
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.748428   0.719200
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.540881   0.595549
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.238994   0.214573
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.600000   0.775000
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  1.000000   1.000000
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.200000   0.111111
# 0   SGD  alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.100000   0.033333
#
#      Recall        F1
# 0  0.500000  0.513436
# 0  1.000000  1.000000
# 0  0.082192  0.013064
# 0  0.171233  0.095325
# 0  0.748428  0.711941
# 0  0.748428  0.711941
# 0  0.748428  0.711941
# 0  0.396226  0.322551
# 0  0.748428  0.711941
# 0  0.748428  0.711941
# 0  0.540881  0.479273
# 0  0.238994  0.182622
# 0  0.600000  0.615000
# 0  1.000000  1.000000
# 0  0.200000  0.120000
# 0  0.100000  0.050000

# %%
try: 
    SGD_Total = pd.concat([SGD_Total, SGD_All], axis=0) 
    # Keep Last Update One 
    SGD_Total = SGD_Total.drop_duplicates( subset = ["Applications","Applications_Condition", "Model"], keep = "last")   
    print("New data is inserted into SGD Total Statistics")
except:
    SGD_Total = SGD_All
    print("First data is inserted into SGD Total Statistics")
# Out:
# New data is inserted into SGD Total Statistics

# %% [markdown]
# ## 6-) `Model Library`

# %%
model_Library_Current
# Out:
#                       process model_type  accuracy  \
# 40af00a1_b0ce  process_2_BERT         NN  0.535556
# d98030a1_05c2  process_2_BERT         NN  0.744444
# 3211f492_628b  process_2_BERT         NN  0.153333
# 2e1208e5_896a  process_2_BERT         NN  0.108889
# 8d8ff70a_e03b  process_2_BERT        SVM       0.3
# ff54cf6e_81fb  process_2_BERT        SVM       0.7
# e7e61604_2b93  process_2_BERT        SVM       0.1
# 1b7c9047_b373  process_2_BERT        SVM       0.1
# 8aee1c8d_90f3  process_2_BERT         DT       0.5
# 58e8b4a0_78c0  process_2_BERT         DT       0.5
# 4c03967b_c533  process_2_BERT         DT       0.8
# 886b37e0_3ad9  process_2_BERT         DT       0.7
# 61aa1221_be11  process_2_BERT         RF       0.6
# 3c7b9790_ec84  process_2_BERT         RF       0.6
# 24062299_8350  process_2_BERT         RF       0.6
# 6211707b_62cc  process_2_BERT         RF       0.6
# f0175dbc_3039  process_2_BERT         GB       0.9
# c88fde04_119b  process_2_BERT         GB       0.9
# 2cd0e9f7_6540  process_2_BERT         GB       0.8
# 34a48988_6495  process_2_BERT         GB       0.6
# 9a83e717_044d  process_2_BERT        SGD       0.6
# 7bdb1dc7_a435  process_2_BERT        SGD       1.0
# 9da2483d_4d9d  process_2_BERT        SGD       0.2
# 6103eb2f_ae70  process_2_BERT        SGD       0.1
#
#                     applications_condition  \
# 40af00a1_b0ce  Out_1_Nor_0_Aut_0_DR_0_NeNe
# d98030a1_05c2  Out_1_Nor_1_Aut_0_DR_0_NeNe
# 3211f492_628b  Out_1_Nor_1_Aut_1_DR_0_NeNe
# 2e1208e5_896a  Out_1_Nor_1_Aut_1_DR_1_NeNe
# 8d8ff70a_e03b       Out_1_Nor_0_Aut_0_DR_0
# ff54cf6e_81fb       Out_1_Nor_1_Aut_0_DR_0
# e7e61604_2b93       Out_1_Nor_1_Aut_1_DR_0
# 1b7c9047_b373       Out_1_Nor_1_Aut_1_DR_1
# 8aee1c8d_90f3       Out_1_Nor_0_Aut_0_DR_0
# 58e8b4a0_78c0       Out_1_Nor_1_Aut_0_DR_0
# 4c03967b_c533       Out_1_Nor_1_Aut_1_DR_0
# 886b37e0_3ad9       Out_1_Nor_1_Aut_1_DR_1
# 61aa1221_be11       Out_1_Nor_0_Aut_0_DR_0
# 3c7b9790_ec84       Out_1_Nor_1_Aut_0_DR_0
# 24062299_8350       Out_1_Nor_1_Aut_1_DR_0
# 6211707b_62cc       Out_1_Nor_1_Aut_1_DR_1
# f0175dbc_3039       Out_1_Nor_0_Aut_0_DR_0
# c88fde04_119b       Out_1_Nor_1_Aut_0_DR_0
# 2cd0e9f7_6540       Out_1_Nor_1_Aut_1_DR_0
# 34a48988_6495       Out_1_Nor_1_Aut_1_DR_1
# 9a83e717_044d       Out_1_Nor_0_Aut_0_DR_0
# 7bdb1dc7_a435       Out_1_Nor_1_Aut_0_DR_0
# 9da2483d_4d9d       Out_1_Nor_1_Aut_1_DR_0
# 6103eb2f_ae70       Out_1_Nor_1_Aut_1_DR_1
#
#                                                     applications  \
# 40af00a1_b0ce  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# d98030a1_05c2  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 3211f492_628b  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 2e1208e5_896a  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 8d8ff70a_e03b  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# ff54cf6e_81fb  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# e7e61604_2b93  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 1b7c9047_b373  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 8aee1c8d_90f3  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 58e8b4a0_78c0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 4c03967b_c533  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 886b37e0_3ad9  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 61aa1221_be11  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 3c7b9790_ec84  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 24062299_8350  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 6211707b_62cc  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# f0175dbc_3039  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# c88fde04_119b  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 2cd0e9f7_6540  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 34a48988_6495  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 9a83e717_044d  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 7bdb1dc7_a435  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 9da2483d_4d9d  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 6103eb2f_ae70  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
#
#                                                            model  \
# 40af00a1_b0ce  <keras.src.engine.functional.Functional object...
# d98030a1_05c2  <keras.src.engine.functional.Functional object...
# 3211f492_628b  <keras.src.engine.functional.Functional object...
# 2e1208e5_896a  <keras.src.engine.functional.Functional object...
# 8d8ff70a_e03b  SVC(C=1, coef0=0.5, degree=2, kernel='poly', r...
# ff54cf6e_81fb  SVC(C=1, coef0=0.5, degree=2, kernel='poly', r...
# e7e61604_2b93  SVC(C=1, coef0=0.5, degree=2, kernel='poly', r...
# 1b7c9047_b373  SVC(C=1, coef0=0.5, degree=2, kernel='poly', r...
# 8aee1c8d_90f3            DecisionTreeClassifier(random_state=42)
# 58e8b4a0_78c0            DecisionTreeClassifier(random_state=42)
# 4c03967b_c533            DecisionTreeClassifier(random_state=42)
# 886b37e0_3ad9            DecisionTreeClassifier(random_state=42)
# 61aa1221_be11  (DecisionTreeClassifier(max_features='sqrt', r...
# 3c7b9790_ec84  (DecisionTreeClassifier(max_features='sqrt', r...
# 24062299_8350  (DecisionTreeClassifier(max_features='sqrt', r...
# 6211707b_62cc  (DecisionTreeClassifier(max_features='sqrt', r...
# f0175dbc_3039  ([DecisionTreeRegressor(criterion='friedman_ms...
# c88fde04_119b  ([DecisionTreeRegressor(criterion='friedman_ms...
# 2cd0e9f7_6540  ([DecisionTreeRegressor(criterion='friedman_ms...
# 34a48988_6495  ([DecisionTreeRegressor(criterion='friedman_ms...
# 9a83e717_044d  SGDClassifier(alpha=0.01, random_state=42, tol...
# 7bdb1dc7_a435  SGDClassifier(alpha=0.01, random_state=42, tol...
# 9da2483d_4d9d  SGDClassifier(alpha=0.01, random_state=42, tol...
# 6103eb2f_ae70  SGDClassifier(alpha=0.01, random_state=42, tol...
#
#                       encoder
# 40af00a1_b0ce  LabelEncoder()
# d98030a1_05c2  LabelEncoder()
# 3211f492_628b  LabelEncoder()
# 2e1208e5_896a  LabelEncoder()
# 8d8ff70a_e03b            None
# ff54cf6e_81fb            None
# e7e61604_2b93            None
# 1b7c9047_b373            None
# 8aee1c8d_90f3            None
# 58e8b4a0_78c0            None
# 4c03967b_c533            None
# 886b37e0_3ad9            None
# 61aa1221_be11            None
# 3c7b9790_ec84            None
# 24062299_8350            None
# 6211707b_62cc            None
# f0175dbc_3039            None
# c88fde04_119b            None
# 2cd0e9f7_6540            None
# 34a48988_6495            None
# 9a83e717_044d            None
# 7bdb1dc7_a435            None
# 9da2483d_4d9d            None
# 6103eb2f_ae70            None

# %%
try: 
    model_Library_Total = pd.concat([model_Library_Total, model_Library_Current], axis=0) 
    # Keep Last Update One 
    model_Library_Total = model_Library_Total.drop_duplicates( subset = ["process","model_type", "accuracy", "model"], keep = "last")   
    print("New data is inserted into SGD Total Statistics")
except:
    model_Library_Total = model_Library_Current
    print("First data is inserted into SGD Total Statistics")
# Out:
# New data is inserted into SGD Total Statistics

# %% [markdown]
# # 3-) `All In One`
# - 1-) SVM
# - 2-) SGD
# - 3-) Decision Tree
# - 4-) Random Forest
# - 5- Gradient Boosting

# %%
NN_Total
# Out:
#                                         Applications  \
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0  ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
#
#         Applications_Condition Model  \
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
# 0  Out_1_Nor_0_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_0_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
# 0  Out_1_Nor_1_Aut_1_DR_1_NeNe  NeNe
#
#                                           Parameters  Accuracy  Precision  \
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.921502   0.941788
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.977959   0.987830
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.082664   0.004756
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.141842   0.108369
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.939400   0.954982
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.920484   0.959412
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.934328   0.956680
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.407762   0.486494
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.933047   0.951347
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.921694   0.960654
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.940650   0.957126
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.425396   0.514291
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.535556   0.481481
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.744444   0.477778
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.153333   0.305556
# 0  exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.108889   0.129630
#
#      Recall        F1
# 0  0.917241  0.906983
# 0  0.986207  0.985653
# 0  0.068966  0.008899
# 0  0.144828  0.118488
# 0  0.943038  0.938256
# 0  0.943038  0.934345
# 0  0.943038  0.933462
# 0  0.405063  0.398171
# 0  0.930380  0.922493
# 0  0.943038  0.934821
# 0  0.936709  0.929353
# 0  0.449367  0.416604
# 0  0.555556  0.470370
# 0  0.666667  0.546296
# 0  0.444444  0.359788
# 0  0.222222  0.142857

# %%
All_Data = pd.concat([NN_Total, SVM_Total, DT_Total, RF_Total, GB_Total, SGD_Total], axis=0) 
All_Data.sort_values(by = ["F1"], ascending= False )
# Out:
#                                          Applications  \
# 0   Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# 0   ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0   Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0   Free_v0_Free_v0_Free_v0_Free_v0_Free_Free_PCA_...
# 0   Free_v0_Free_v0_Free_v0_Denoising_v0_Free_Free...
# ..                                                ...
# 0   ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0   ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0   ZScore_v0_ZScore_v0_Basic_v1_Basic_v1_Standard...
# 0   ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
# 0   ZScore_v0_ZScore_v0_Dropout_v1_Denoising_v0_St...
#
#          Applications_Condition Model  \
# 0        Out_1_Nor_0_Aut_0_DR_0    RF
# 0        Out_1_Nor_1_Aut_0_DR_0   SVM
# 0        Out_1_Nor_1_Aut_1_DR_0    RF
# 0        Out_1_Nor_0_Aut_0_DR_0    RF
# 0        Out_1_Nor_1_Aut_0_DR_0    RF
# ..                          ...   ...
# 0        Out_1_Nor_1_Aut_1_DR_1   SVM
# 0        Out_1_Nor_1_Aut_1_DR_1   SGD
# 0        Out_1_Nor_1_Aut_1_DR_0   SVM
# 0        Out_1_Nor_1_Aut_1_DR_0   SGD
# 0   Out_1_Nor_1_Aut_1_DR_0_NeNe  NeNe
#
#                                            Parameters  Accuracy  Precision  \
# 0                                               Basic  1.000000   1.000000
# 0      kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  1.000000   1.000000
# 0                                               Basic  1.000000   1.000000
# 0                                               Basic  1.000000   1.000000
# 0                                               Basic  1.000000   1.000000
# ..                                                ...       ...        ...
# 0      kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.100000   0.033333
# 0      alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.100000   0.033333
# 0      kernel_poly_degree_2_coef0_0.5_C_1_gamma_scale  0.100000   0.020000
# 0      alpha_0.01_max_iter_1000_penalty_l2_tol_0.0001  0.082192   0.007096
# 0   exp_p0: {'GaussianNoise': 0.1}, exp_p1: {'Dens...  0.082664   0.004756
#
#       Recall        F1
# 0   1.000000  1.000000
# 0   1.000000  1.000000
# 0   1.000000  1.000000
# 0   1.000000  1.000000
# 0   1.000000  1.000000
# ..       ...       ...
# 0   0.100000  0.050000
# 0   0.100000  0.050000
# 0   0.100000  0.033333
# 0   0.082192  0.013064
# 0   0.068966  0.008899
#
# [84 rows x 8 columns]

# %% [markdown]
# ---
# # `End`
# - 1-) SVM
# - 2-) SGD
# - 3-) Decision Tree
# - 4-) Random Forest
# - 5- Gradient Boosting

# %%
export_name = "NN_Total"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_total}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(NN_Total, file)

# %%
export_name = "SVM_Total"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_total}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(SVM_Total, file)

# %%
export_name = "DT_Total"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_total}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(DT_Total, file)

# %%
export_name = "RF_Total"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_total}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(RF_Total, file)

# %%
export_name = "GB_Total"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_total}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(GB_Total, file)

# %%
export_name = "SGD_Total"
with open(os.path.join(access_data_path(f"{process_barcode}/data/{folder_total}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(SGD_Total, file)

# %%
export_name = "model_Library_Total"
with open(os.path.join(access_data_path(f"{process_barcode}/model/library", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(model_Library_Total, file)
