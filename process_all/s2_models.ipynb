# %%
# %run s0_config.ipynb

# %% [markdown]
# # 1-) `Models`

# %%
# models 
## Process 1
## BERT
process_barcode = "process_4"

model_Library_Total_Process_4_Path = access_data_path(f"{process_barcode}/model/library", "model_Library_Total.pkl") 

with open(model_Library_Total_Process_4_Path , 'rb') as file:
    model_Library_Total_Process_4 = pickle.load(file)

# %%
# models 
## Process 1
## BERT
process_barcode = "process_4"

models_4_SVM_Path = access_data_path(f"{process_barcode}/model", "SVM_All_Models.pkl") 
models_4_SGD_Path = access_data_path(f"{process_barcode}/model", "SGD_All_Models.pkl") 
models_4_DT_Path  = access_data_path(f"{process_barcode}/model", "DT_All_Models.pkl") 
models_4_GB_Path  = access_data_path(f"{process_barcode}/model", "GB_All_Models.pkl") 
models_4_NN_Path  = access_data_path(f"{process_barcode}/model", "NN_All_Models.pkl") 
models_4_RF_Path  = access_data_path(f"{process_barcode}/model", "RF_All_Models.pkl") 

with open(models_4_SVM_Path , 'rb') as file:
    models_4_SVM = pickle.load(file) 

with open(models_4_SGD_Path , 'rb') as file:
    models_4_SGD = pickle.load(file) 

with open(models_4_DT_Path , 'rb') as file:
    models_4_DT = pickle.load(file) 


with open(models_4_NN_Path , 'rb') as file:
    models_4_NN = pickle.load(file) 

with open(models_4_RF_Path , 'rb') as file:
    models_4_RF = pickle.load(file)

# %%
models_4_All = { "P4_SVM": models_4_SVM,
                      "P4_SGD": models_4_SGD,
                      "P4_DT": models_4_DT,
                      "P4_NN": models_4_NN,
                      "P4_RF": models_4_RF
                    }

# %% [markdown]
# ---
# ### Process 1

# %% [markdown]
# #### P1 | BERT
# - Process: 1
# - Language Model: BERT
# - Input: Text Embeddings
# - Prediction: Cell Type
# - Models: NN, SVM, SGD, DT, RF, GB

# %%
# models 
## Process 1
## BERT
process_barcode = "process_1_BERT"

model_Library_Total_Process_1_BERT_Path = access_data_path(f"{process_barcode}/model/library", "model_Library_Total.pkl") 

with open(model_Library_Total_Process_1_BERT_Path , 'rb') as file:
    model_Library_Total_Process_1_BERT = pickle.load(file)

# %%
# models 
## Process 1
## BERT
process_barcode = "process_1_BERT"

models_1_BERT_SVM_Path = access_data_path(f"{process_barcode}/model", "SVM_All_Models.pkl") 
models_1_BERT_SGD_Path = access_data_path(f"{process_barcode}/model", "SGD_All_Models.pkl") 
models_1_BERT_DT_Path  = access_data_path(f"{process_barcode}/model", "DT_All_Models.pkl") 
models_1_BERT_NN_Path  = access_data_path(f"{process_barcode}/model", "NN_All_Models.pkl") 
models_1_BERT_RF_Path  = access_data_path(f"{process_barcode}/model", "RF_All_Models.pkl") 

with open(models_1_BERT_SVM_Path , 'rb') as file:
    models_1_BERT_SVM = pickle.load(file) 

with open(models_1_BERT_SGD_Path , 'rb') as file:
    models_1_BERT_SGD = pickle.load(file) 

with open(models_1_BERT_DT_Path , 'rb') as file:
    models_1_BERT_DT = pickle.load(file) 

with open(models_1_BERT_NN_Path , 'rb') as file:
    models_1_BERT_NN = pickle.load(file) 

with open(models_1_BERT_RF_Path , 'rb') as file:
    models_1_BERT_RF = pickle.load(file)

# %%
models_1_BERT_All = { "P1_BERT_SVM": models_1_BERT_SVM,
                      "P1_BERT_SGD": models_1_BERT_SGD,
                      "P1_BERT_DT": models_1_BERT_DT,
                      "P1_BERT_NN": models_1_BERT_NN,
                      "P1_BERT_RF": models_1_BERT_RF
                    }

# %% [markdown]
# #### P1 | GPT2
# - Process: 1
# - Language Model: GPT2
# - Input: Text Embeddings
# - Prediction: Cell Type
# - Models: NN, SVM, SGD, DT, RF, GB

# %%
# models 
## Process 1
## GPT2
process_barcode = "process_1_GPT2"

model_Library_Total_Process_1_GPT2_Path = access_data_path(f"{process_barcode}/model/library", "model_Library_Total.pkl") 

with open(model_Library_Total_Process_1_GPT2_Path , 'rb') as file:
    model_Library_Total_Process_1_GPT2 = pickle.load(file)

# %%
# models 
## Process 1
## GPT2
process_barcode = "process_1_GPT2"

models_1_GPT2_SVM_Path = access_data_path(f"{process_barcode}/model", "SVM_All_Models.pkl") 
models_1_GPT2_SGD_Path = access_data_path(f"{process_barcode}/model", "SGD_All_Models.pkl") 
models_1_GPT2_DT_Path  = access_data_path(f"{process_barcode}/model", "DT_All_Models.pkl") 
models_1_GPT2_NN_Path  = access_data_path(f"{process_barcode}/model", "NN_All_Models.pkl") 
models_1_GPT2_RF_Path  = access_data_path(f"{process_barcode}/model", "RF_All_Models.pkl") 

with open(models_1_GPT2_SVM_Path , 'rb') as file:
    models_1_GPT2_SVM = pickle.load(file) 

with open(models_1_GPT2_SGD_Path , 'rb') as file:
    models_1_GPT2_SGD = pickle.load(file) 

with open(models_1_GPT2_DT_Path , 'rb') as file:
    models_1_GPT2_DT = pickle.load(file) 


with open(models_1_GPT2_NN_Path , 'rb') as file:
    models_1_GPT2_NN = pickle.load(file) 

with open(models_1_GPT2_RF_Path , 'rb') as file:
    models_1_GPT2_RF = pickle.load(file) 

models_1_GPT2_All = [models_1_GPT2_SVM, models_1_GPT2_SGD, models_1_GPT2_DT, models_1_GPT2_NN, models_1_GPT2_RF]

# %%
models_1_GPT2_All = { "P1_GPT2_SVM": models_1_GPT2_SVM,
                      "P1_GPT2_SGD": models_1_GPT2_SGD,
                      "P1_GPT2_DT": models_1_GPT2_DT,
                      "P1_GPT2_NN": models_1_GPT2_NN,
                      "P1_GPT2_RF": models_1_GPT2_RF
                    }

# %% [markdown]
# #### P1 | GPT3
# - Process: 1
# - Language Model: GPT3
# - Input: Text Embeddings
# - Prediction: Cell Type
# - Models: NN, SVM, SGD, DT, RF, GB

# %%
# models 
## Process 1
## GPT3
process_barcode = "process_1_GPT3"

model_Library_Total_Process_1_GPT3_Path = access_data_path(f"{process_barcode}/model/library", "model_Library_Total.pkl") 

with open(model_Library_Total_Process_1_GPT3_Path , 'rb') as file:
    model_Library_Total_Process_1_GPT3 = pickle.load(file)

# %%
# models 
## Process 1
## GPT3
process_barcode = "process_1_GPT3"

models_1_GPT3_SVM_Path = access_data_path(f"{process_barcode}/model", "SVM_All_Models.pkl") 
models_1_GPT3_SGD_Path = access_data_path(f"{process_barcode}/model", "SGD_All_Models.pkl") 
models_1_GPT3_DT_Path  = access_data_path(f"{process_barcode}/model", "DT_All_Models.pkl") 
models_1_GPT3_NN_Path  = access_data_path(f"{process_barcode}/model", "NN_All_Models.pkl") 
models_1_GPT3_RF_Path  = access_data_path(f"{process_barcode}/model", "RF_All_Models.pkl") 

with open(models_1_GPT3_SVM_Path , 'rb') as file:
    models_1_GPT3_SVM = pickle.load(file) 

with open(models_1_GPT3_SGD_Path , 'rb') as file:
    models_1_GPT3_SGD = pickle.load(file) 

with open(models_1_GPT3_DT_Path , 'rb') as file:
    models_1_GPT3_DT = pickle.load(file) 


with open(models_1_GPT3_NN_Path , 'rb') as file:
    models_1_GPT3_NN = pickle.load(file) 

with open(models_1_GPT3_RF_Path , 'rb') as file:
    models_1_GPT3_RF = pickle.load(file) 

models_1_GPT3_All = [models_1_GPT3_SVM, models_1_GPT3_SGD, models_1_GPT3_DT, models_1_GPT3_NN, models_1_GPT3_RF]

# %%
models_1_GPT3_All = { "P1_GPT3_SVM": models_1_GPT3_SVM,
                      "P1_GPT3_SGD": models_1_GPT3_SGD,
                      "P1_GPT3_DT": models_1_GPT3_DT,
                      "P1_GPT3_NN": models_1_GPT3_NN,
                      "P1_GPT3_RF": models_1_GPT3_RF
                    }

# %% [markdown]
# #### P1 | Total

# %%
models_1_All = { "P1_BERT": models_1_BERT_All,
                 "P1_GPT2": models_1_GPT2_All,
                 "P1_GPT3": models_1_GPT3_All}

# %% [markdown]
# ---
# ### Process 2

# %% [markdown]
# #### P2 | BERT
# - Process: 2
# - Language Model: BERT
# - Input: Text Embeddings
# - Prediction: Cell Type
# - Models: NN, SVM, SGD, DT, RF, GB

# %%
# models 
## Process 2
## BERT
process_barcode = "process_2_BERT"

model_Library_Total_Process_2_BERT_Path = access_data_path(f"{process_barcode}/model/library", "model_Library_Total.pkl") 

with open(model_Library_Total_Process_2_BERT_Path , 'rb') as file:
    model_Library_Total_Process_2_BERT = pickle.load(file)

# %%
# models 
## Process 1
## BERT
process_barcode = "process_2_BERT"

models_2_BERT_SVM_Path = access_data_path(f"{process_barcode}/model", "SVM_All_Models.pkl") 
models_2_BERT_SGD_Path = access_data_path(f"{process_barcode}/model", "SGD_All_Models.pkl") 
models_2_BERT_DT_Path  = access_data_path(f"{process_barcode}/model", "DT_All_Models.pkl") 
models_2_BERT_NN_Path  = access_data_path(f"{process_barcode}/model", "NN_All_Models.pkl") 
models_2_BERT_RF_Path  = access_data_path(f"{process_barcode}/model", "RF_All_Models.pkl") 

with open(models_2_BERT_SVM_Path , 'rb') as file:
    models_2_BERT_SVM = pickle.load(file) 

with open(models_2_BERT_SGD_Path , 'rb') as file:
    models_2_BERT_SGD = pickle.load(file) 

with open(models_2_BERT_DT_Path , 'rb') as file:
    models_2_BERT_DT = pickle.load(file) 


with open(models_2_BERT_NN_Path , 'rb') as file:
    models_2_BERT_NN = pickle.load(file) 

with open(models_2_BERT_RF_Path , 'rb') as file:
    models_2_BERT_RF = pickle.load(file) 

models_2_BERT_All = [models_2_BERT_SVM, models_2_BERT_SGD, models_2_BERT_DT, models_2_BERT_NN, models_2_BERT_RF]

# %%
models_2_BERT_All = { "P2_BERT_SVM": models_1_BERT_SVM,
                      "P2_BERT_SGD": models_1_BERT_SGD,
                      "P2_BERT_DT": models_1_BERT_DT,
                      "P2_BERT_NN": models_1_BERT_NN,
                      "P2_BERT_RF": models_1_BERT_RF
                    }

# %% [markdown]
# #### P2 | GPT2
# - Process: 2
# - Language Model: GPT2
# - Input: Text Embeddings
# - Prediction: Cell Type
# - Models: NN, SVM, SGD, DT, RF, GB

# %%
# models 
## Process 2
## GPT2
process_barcode = "process_2_GPT2"

model_Library_Total_Process_2_GPT2_Path = access_data_path(f"{process_barcode}/model/library", "model_Library_Total.pkl") 

with open(model_Library_Total_Process_2_GPT2_Path , 'rb') as file:
    model_Library_Total_Process_2_GPT2 = pickle.load(file)

# %%
# models 
## Process 2
## GPT2
process_barcode = "process_2_GPT2"

models_2_GPT2_SVM_Path = access_data_path(f"{process_barcode}/model", "SVM_All_Models.pkl") 
models_2_GPT2_SGD_Path = access_data_path(f"{process_barcode}/model", "SGD_All_Models.pkl") 
models_2_GPT2_DT_Path  = access_data_path(f"{process_barcode}/model", "DT_All_Models.pkl") 
models_2_GPT2_NN_Path  = access_data_path(f"{process_barcode}/model", "NN_All_Models.pkl") 
models_2_GPT2_RF_Path  = access_data_path(f"{process_barcode}/model", "RF_All_Models.pkl") 

with open(models_2_GPT2_SVM_Path , 'rb') as file:
    models_2_GPT2_SVM = pickle.load(file) 

with open(models_2_GPT2_SGD_Path , 'rb') as file:
    models_2_GPT2_SGD = pickle.load(file) 

with open(models_2_GPT2_DT_Path , 'rb') as file:
    models_2_GPT2_DT = pickle.load(file) 

with open(models_2_GPT2_NN_Path , 'rb') as file:
    models_2_GPT2_NN = pickle.load(file) 

with open(models_2_GPT2_RF_Path , 'rb') as file:
    models_2_GPT2_RF = pickle.load(file)

# %%
models_2_GPT2_All = { "P2_GPT2_SVM": models_2_GPT2_SVM,
                      "P2_GPT2_SGD": models_2_GPT2_SGD,
                      "P2_GPT2_DT": models_2_GPT2_DT,
                      "P2_GPT2_NN": models_2_GPT2_NN,
                      "P2_GPT2_RF": models_2_GPT2_RF
                    }

# %% [markdown]
# #### P2 | GPT3
# - Process: 2
# - Language Model: GPT3
# - Input: Text Embeddings
# - Prediction: Cell Type
# - Models: NN, SVM, SGD, DT, RF, GB

# %%
# models 
## Process 2
## GPT3
process_barcode = "process_2_GPT3"

model_Library_Total_Process_2_GPT3_Path = access_data_path(f"{process_barcode}/model/library", "model_Library_Total.pkl") 

with open(model_Library_Total_Process_2_GPT3_Path , 'rb') as file:
    model_Library_Total_Process_2_GPT3 = pickle.load(file)

# %%
# models 
## Process 2
## GPT3
process_barcode = "process_2_GPT3"

models_2_GPT3_SVM_Path = access_data_path(f"{process_barcode}/model", "SVM_All_Models.pkl") 
models_2_GPT3_SGD_Path = access_data_path(f"{process_barcode}/model", "SGD_All_Models.pkl") 
models_2_GPT3_DT_Path  = access_data_path(f"{process_barcode}/model", "DT_All_Models.pkl") 
models_2_GPT3_NN_Path  = access_data_path(f"{process_barcode}/model", "NN_All_Models.pkl") 
models_2_GPT3_RF_Path  = access_data_path(f"{process_barcode}/model", "RF_All_Models.pkl") 

with open(models_2_GPT3_SVM_Path , 'rb') as file:
    models_2_GPT3_SVM = pickle.load(file) 

with open(models_2_GPT3_SGD_Path , 'rb') as file:
    models_2_GPT3_SGD = pickle.load(file) 

with open(models_2_GPT3_DT_Path , 'rb') as file:
    models_2_GPT3_DT = pickle.load(file) 


with open(models_2_GPT3_NN_Path , 'rb') as file:
    models_2_GPT3_NN = pickle.load(file) 

with open(models_2_GPT3_RF_Path , 'rb') as file:
    models_2_GPT3_RF = pickle.load(file)

# %%
models_2_GPT3_All = { "P2_GPT3_SVM": models_2_GPT3_SVM,
                      "P2_GPT3_SGD": models_2_GPT3_SGD,
                      "P2_GPT3_DT": models_2_GPT3_DT,
                      "P2_GPT3_NN": models_2_GPT3_NN,
                      "P2_GPT3_RF": models_2_GPT3_RF
                    }

# %% [markdown]
# #### P2 | Total

# %%
models_2_All = { "P2_BERT": models_2_BERT_All,
                 "P2_GPT2": models_2_GPT2_All,
                 "P2_GPT3": models_2_GPT3_All}

# %% [markdown]
# # 2-) `Process All`

# %%
models_All_Models = { "P1": models_1_All,
                      "P2": models_2_All }

# %%
models_All_Models
# Out:
# {'P1': {'P1_BERT': {'P1_BERT_SVM': [Pipeline(steps=[('scaler', StandardScaler()), ('normalizer', MinMaxScaler()),
#                     ('smote', SMOTE(random_state=42)),
#                     ('svc',
#                      OneVsRestClassifier(estimator=SVC(C=10,
#                                                        class_weight='balanced',
#                                                        coef0=0.5, kernel='poly',
#                                                        random_state=42),
#                                          n_jobs=-1))])],
#    'P1_BERT_SGD': [Pipeline(steps=[('scaler', StandardScaler()), ('smote', SMOTE(random_state=42)),
#                     ('sgd',
#                      OneVsRestClassifier(estimator=SGDClassifier(alpha=0.001,
#                                                                  loss='log_loss',
#                                                                  penalty='elasticnet',
# ...

# %%
model_Library_1_All_In_One = pd.concat([model_Library_Total_Process_1_BERT, model_Library_Total_Process_1_GPT2, model_Library_Total_Process_1_GPT3], axis=0) 
model_Library_2_All_In_One = pd.concat([model_Library_Total_Process_2_BERT, model_Library_Total_Process_2_GPT2, model_Library_Total_Process_2_GPT3], axis=0) 
model_Library_1_2_All_In_One = pd.concat([model_Library_1_All_In_One, model_Library_2_All_In_One], axis=0)

# %% [markdown]
# # 3-) `Model Library`

# %%
model_Library_1_2_All_In_One
# Out:
#                       process     model_type  accuracy  \
# 1dc1bc00_5e2f  process_1_BERT             NN    0.9012
# 72bc6864_4bc1  process_1_BERT            SVM  0.998117
# 194bd31d_2ba9  process_1_BERT            SGD  0.967985
# 0265ea78_0747  process_1_BERT             DT  0.694915
# 74597569_0f7c  process_1_BERT             RF  0.934087
# ...                       ...            ...       ...
# ad1712aa_14e4  process_2_GPT3            SGD  0.991509
# fad15f9f_a248  process_2_GPT3            SGD  0.992453
# 471227e4_09df  process_2_GPT3            SGD  0.990094
# 03604ce5_ae8a  process_2_GPT3  Decision Tree  0.963208
# 37fa5100_d209  process_2_GPT3  Random Forest  0.993868
#
#                    applications_condition  \
# 1dc1bc00_5e2f      Out_1_Nor_1_Aut_1_DR_1
# 72bc6864_4bc1      Out_1_Nor_1_Aut_1_DR_1
# 194bd31d_2ba9      Out_1_Nor_1_Aut_1_DR_1
# 0265ea78_0747      Out_1_Nor_1_Aut_1_DR_1
# 74597569_0f7c      Out_1_Nor_1_Aut_1_DR_1
# ...                                   ...
# ...

# %%
model_Library_2_All_In_One
# Out:
#                       process     model_type  accuracy  \
# 3646bc9b_8e02  process_2_BERT             NN  0.979746
# f66605fa_0aa9  process_2_BERT            SVM  0.988903
# 69c87526_fd57  process_2_BERT            SVM  0.987513
# bc3226e1_6eea  process_2_BERT            SVM  0.990289
# 67bc664d_4389  process_2_BERT            SVM  0.989943
# ...                       ...            ...       ...
# ad1712aa_14e4  process_2_GPT3            SGD  0.991509
# fad15f9f_a248  process_2_GPT3            SGD  0.992453
# 471227e4_09df  process_2_GPT3            SGD  0.990094
# 03604ce5_ae8a  process_2_GPT3  Decision Tree  0.963208
# 37fa5100_d209  process_2_GPT3  Random Forest  0.993868
#
#                    applications_condition  \
# 3646bc9b_8e02      Out_1_Nor_1_Aut_1_DR_1
# f66605fa_0aa9  Out_1_Nor_1_Aut_1_DR_1_SVM
# 69c87526_fd57  Out_1_Nor_1_Aut_1_DR_1_SVM
# bc3226e1_6eea  Out_1_Nor_1_Aut_1_DR_1_SVM
# 67bc664d_4389  Out_1_Nor_1_Aut_1_DR_1_SVM
# ...                                   ...
# ...

# %% [markdown]
# ---
# # `End`

# %%
process_barcode = "process_3"
folder_text     = "process_1" 

export_name = "models_1_All" 
with open(os.path.join(access_data_path(f"{process_barcode}/models/{folder_text}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(models_1_All, file)   


folder_text = "process_2" 
export_name = "models_2_All" 
with open(os.path.join(access_data_path(f"{process_barcode}/models/{folder_text}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(models_2_All, file)   


folder_text = "all" 
export_name = "models_All" 
with open(os.path.join(access_data_path(f"{process_barcode}/models/{folder_text}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(models_All_Models, file)

# %%
model_Library_1_All_In_One = pd.concat([model_Library_Total_Process_1_BERT, model_Library_Total_Process_1_GPT2, model_Library_Total_Process_1_GPT3], axis=0) 
model_Library_2_All_In_One = pd.concat([model_Library_Total_Process_2_BERT, model_Library_Total_Process_2_GPT2, model_Library_Total_Process_2_GPT3], axis=0) 
model_Library_1_2_All_In_One = pd.concat([model_Library_1_All_In_One, model_Library_2_All_In_One], axis=0)

# %%
folder_text = "library" 
export_name = "model_Library_1_All_In_One" 
with open(os.path.join(access_data_path(f"{process_barcode}/models/{folder_text}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(model_Library_1_All_In_One, file)   

export_name = "model_Library_2_All_In_One" 
with open(os.path.join(access_data_path(f"{process_barcode}/models/{folder_text}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(model_Library_2_All_In_One, file)   

export_name = "model_Library_1_2_All_In_One" 
with open(os.path.join(access_data_path(f"{process_barcode}/models/{folder_text}", f"{export_name}" + ".pkl"))  , 'wb') as file: 
    pickle.dump(model_Library_1_2_All_In_One, file)
